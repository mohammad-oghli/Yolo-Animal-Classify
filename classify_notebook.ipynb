# %%
from model import classify_model, detection_model
import matplotlib.pyplot as plt


source = "data/animal2.jpg"
name, conf = classify_model(source)
result_img = detection_model(source)
print(name, conf)
plt.imshow(result_img)
# Out:
# 0: 224x224 American_black_bear 0.61, brown_bear 0.27, sloth_bear 0.04, marmoset 0.02, kelpie 0.01, 4.7ms
# Speed: 4.2ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 bear, 30.1ms
# Speed: 1.0ms preprocess, 30.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 American_black_bear 0.61, brown_bear 0.27, sloth_bear 0.04, marmoset 0.02, kelpie 0.01, 5.3ms
# Speed: 4.4ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# American black bear 0.61487
